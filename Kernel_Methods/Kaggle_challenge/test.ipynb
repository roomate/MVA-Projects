# %% [markdown]
# This is a test notebook for these kernels classifiers.

# %%
from KFDA import Fisher_discriminant
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# %%
class plot_data():
    def __init__(self, x_min, y_min, x_max, y_max, size):
        
        # limit of x-axis
        self.x_min, self.x_max = x_min, x_max

        # limit of y-axis
        self.y_min, self.y_max = y_min, y_max

        # size of the figure
        self.size = size

        if not isinstance(size, tuple):
            raise ValueError("The size should be a tuple of two ints")

    def plot_binary_class(self, X, Y):
        """
        X : float(nb_sample, n_dim = 2) stores the coordinates of the points.
        Y : bool(nb_sample) stores the labels
        """
        fig, ax = plt.subplots(1,1,figsize = self.size)
        class_1 = X[Y == 0]
        class_2 = X[Y == 1]
        ax.scatter(class_1[:,0], class_1[:,1], color = 'r')
        ax.scatter(class_2[:,0], class_2[:,1], color = 'b')
        ax.set_xlim(self.x_min, self.x_max)
        ax.set_ylim(self.y_min, self.y_max)

# %%
class gaussian_kernel:
    def __init__(self, sigma):
        self.sigma = sigma
    def kernel(self, X):
        """
        X: float(nb_sample, 2)
        sigma: float. It is the bandwidth of the kernel
        """
        diff = X[None,:,:] - X[:,None,:]
        return np.exp(-np.sum(diff**2)/(2*self.sigma))

# %%
X, Y = make_moons(n_samples=2000, noise=0.1)

x_min, x_max = -1.5, 2.5
y_min, y_max = -1, 1.5

plot = plot_data(x_min, y_min, x_max, y_max, size = (8,6))
plot.plot_binary_class(X,Y)

# %%
g_kernel = gaussian_kernel(1/2)

Kernel_Fisher = Fisher_discriminant(kernel = g_kernel.kernel, nb_class = 2)

Kernel_Fisher.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 5
#       1 g_kernel = gaussian_kernel(1/2)
#       3 Kernel_Fisher = Fisher_discriminant(kernel = g_kernel.kernel, nb_class = 2)
# ----> 5 Kernel_Fisher.fit(X,Y)
#
# File \\wsl.localhost\Ubuntu\home\Projet_MVA\Kernel_Methods\KFDA.py:95, in Fisher_discriminant.fit(self, data_x, data_y)
#      93     return 0
#      94 self.N = data_x.shape[0]
# ---> 95 self.gram = self._Gram(data_x, data_x)
#      96 self._count_class(data_y)
#      97 M_matri, N_matrix = self.M_matrix(data_x, data_y)
#
# File \\wsl.localhost\Ubuntu\home\Projet_MVA\Kernel_Methods\KFDA.py:24, in Fisher_discriminant._Gram(self, data_x, data_x_p)
#      20 def _Gram(self,data_x,data_x_p):
#      21     """
#      22     Compute the gram matrix given the dataset data_x and data_x_p
#      23     """
# ---> 24     kern = np.empty((data_x.shape[0], data_x_p.shape[0]))
#      25     if (data_x_p.shape[0] == data_x.shape[0]):
#      26         for i in range(data_x.shape[0]):
#
# NameError: name 'np' is not defined
